# %% [markdown]
# import libraries, read and view train and test data, ignore any warnings

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
from IPython.display import display # this is to display multiple statements in one block of jupyter
train=pd.read_csv("C:/Users/bachh/OneDrive/Desktop/Self/train_loan.csv")
test=pd.read_csv("C:/Users/bachh/OneDrive/Desktop/Self/test_loan.csv")
display(train.head())
display(train.info())
display(test.info())
display(train.describe())
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %% [markdown]
# check for columns, data type and shape of the data

# %%
display(train.columns)
display(test.columns)
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
display(train.dtypes)
display(test.dtypes)
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome      int64
# LoanAmount           float64
# Loan_Amount_Term       int64
# Credit_History       float64
# Property_Area         object
# dtype: object

# %%
display(train.shape)
display(test.shape)
# Out:
# (614, 13)
# (120, 12)

# %% [markdown]
# Univariate Analysis

# %%
#target variable
display(train['Loan_Status'].value_counts())
display(train['Loan_Status'].value_counts(normalize='true')) ## to print proportion
display(train['Loan_Status'].value_counts().plot.bar())
# Out:
# Y    422
# N    192
# Name: Loan_Status, dtype: int64
# Y    0.687296
# N    0.312704
# Name: Loan_Status, dtype: float64

# %%
# independent categorical and ordinal variables
plt.subplot(3,3,1)
train['Gender'].value_counts(normalize='true').plot.bar(figsize=(20,10), title='Gender')
plt.subplot(3,3,2)
train['Married'].value_counts(normalize='true').plot.bar(figsize=(20,10), title='Married?')
plt.subplot(3,3,3)
train['Education'].value_counts(normalize='true').plot.bar(figsize=(20,10), title='Education')
plt.subplot(3,3,4)
train['Credit_History'].value_counts(normalize='true').plot.bar(figsize=(20,10), title='Paid loans?')
plt.subplot(3,3,5)
train['Self_Employed'].value_counts(normalize='true').plot.bar(figsize=(20,10), title='Self_employed?')
plt.subplot(3,3,6)
train['Property_Area'].value_counts(normalize='true').plot.bar(figsize=(20,10), title='Property area')
plt.subplot(3,3,7)
train['Dependents'].value_counts(normalize='true').plot.bar(figsize=(20,10), title='Dependents')

# %%
# independent numerical variables
plt.figure(80)
plt.subplot(2,2,1)
train['ApplicantIncome'].plot.box(figsize=(10,10))
plt.subplot(2,2,2)
sns.distplot(train['CoapplicantIncome'])
plt.subplot(2,2,3)
sns.distplot(train['Loan_Amount_Term'])
plt.show()

# %%
train.boxplot(column='ApplicantIncome',by='Education')

# %%
train['CoapplicantIncome'].plot.box()

# %%
df=train.dropna()
plt.subplot(121)
sns.distplot(df['LoanAmount'])
plt.subplot(122)
plt.boxplot(df['LoanAmount'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c3a0ab0f98>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1c3a0acf668>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1c3a0ab0ba8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c3a0acfcf8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c3a0acfdd8>],
#  'means': []}

# %% [markdown]
# Bivariate analysis

# %%
##categorical vs target
Gender=pd.crosstab(train['Gender'], train['Loan_Status'])
Gender.div(Gender.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)

# %%
Marr=pd.crosstab(train['Married'], train['Loan_Status'])
Marr.div(Marr.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)
dep=pd.crosstab(train['Dependents'], train['Loan_Status'])
dep.div(dep.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)
Edu=pd.crosstab(train['Gender'], train['Loan_Status'])
Edu.div(Edu.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)
self=pd.crosstab(train['Self_Employed'], train['Loan_Status'])
self.div(self.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)
Cred=pd.crosstab(train['Credit_History'], train['Loan_Status'])
Cred.div(Cred.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)
prop=pd.crosstab(train['Property_Area'], train['Loan_Status'])
prop.div(prop.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)

# %% [markdown]
# numerical independent variables vs target

# %%
##make bins of income and find average income of approved and non approved people
bins=[0,2500,4000,6000,81000]
group=['Low','Average','High', 'Very high'] 
train['Income_bin']=pd.cut(df['ApplicantIncome'],bins,labels=group)
ibin=pd.crosstab(train['Income_bin'], train['Loan_Status'])
ibin.div(ibin.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)

# %% [markdown]
# lets analyse coapplicant income in the similar fashion

# %%
bins=[0,1000,3000,42000]
group=['Low','Average','High'] 
train['coIncome_bin']=pd.cut(df['CoapplicantIncome'],bins,labels=group)
cobin=pd.crosstab(train['coIncome_bin'], train['Loan_Status'])
cobin.div(cobin.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)

# %% [markdown]
# lets add the income of applicant and coapplicant to see if the total income has any impact

# %%
train['Total_Income']=train['ApplicantIncome']+train['CoapplicantIncome']
bins=[0,2500,4000,6000,83000] 
group=['Low','Average','High', 'Very high']
train['Total_Income_bin']=pd.cut(train['Total_Income'],bins,labels=group)
totbin=pd.crosstab(train['Total_Income_bin'], train['Loan_Status'])
totbin.div(totbin.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)

# %%
# loan amount vs target
bins=[0,100,200,700] 
group=['Low','Average','High']
train['loanbin']=pd.cut(df['LoanAmount'],bins,labels=group)
loanbin=pd.crosstab(train['loanbin'], train['Loan_Status'])
loanbin.div(loanbin.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)

# %%
## convert values in dependent columns from 3+ to 3 and loan_status to boolean (0,1)
train=train.drop(['Income_bin', 'coIncome_bin', 'loanbin', 'Total_Income_bin', 'Total_Income'], axis=1)
train['Dependents'].replace('3+', 3,inplace=True) 
test['Dependents'].replace('3+', 3,inplace=True) 
train['Loan_Status'].replace('N', 0,inplace=True) 
train['Loan_Status'].replace('Y', 1,inplace=True)

# %% [markdown]
# correlation between numerical variables

# %%
matrix = train.corr() 
sns.heatmap(matrix, vmax=.7,cmap="BuGn");

# %% [markdown]
# treatment of missing values using mean and median [for numerical], mode [for categorical]

# %%
train.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#impute missing values in categorical
train['Gender'].fillna(train['Gender'].mode()[0], inplace=True)
train['Married'].fillna(train['Married'].mode()[0], inplace=True) 
train['Dependents'].fillna(train['Dependents'].mode()[0], inplace=True) 
train['Self_Employed'].fillna(train['Self_Employed'].mode()[0], inplace=True) 
train['Credit_History'].fillna(train['Credit_History'].mode()[0], inplace=True)

#impute missing values in numerical
train['Loan_Amount_Term'].fillna(train['Loan_Amount_Term'].mode()[0], inplace=True)
train['LoanAmount'].fillna(train['LoanAmount'].median(), inplace=True)

# %%
train.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# outlier treatment

# %%
train['LoanAmount_log'] = np.log(train['LoanAmount']) 
train['LoanAmount_log'].hist(bins=20)
test['LoanAmount_log'] = np.log(test['LoanAmount'])

# %% [markdown]
# confusion matrix
# Precision = TP / (TP + FP)   measure of correctness achieved in true prediction
# Recall = TP / (TP + FN)      measure of actual observations which are predicted correctly
# Specificity = TN / (TN + FP) measure of how many observations of false class are labeled correctly.
#
# ROC curve
#
# Receiver Operating Characteristic(ROC)- summarizes the model’s performance by evaluating
# the trade offs between true positive rate (sensitivity) and false positive rate(1- specificity).
#
# AUC-referred to as index of accuracy(A) or concordance index,
# is a perfect performance metric for ROC curve. Higher the area under curve, better the prediction power of the model.

# %% [markdown]
# Model 1 : Logistic Regression

# %%
# drop Loan_ID, as it has no role in predicting the final value
train=train.drop('Loan_ID',axis=1) 
test=test.drop('Loan_ID',axis=1)

# %%
# scikit learn want you to drop loan_status from train and save it somewhere else
X = train.drop('Loan_Status',1) 
y = train.Loan_Status

# %%
#dummy variables for categorical variables
X=pd.get_dummies(X) 
train=pd.get_dummies(train) 
test=pd.get_dummies(test)

# %%
from sklearn.model_selection import train_test_split
x_train, x_cv, y_train, y_cv = train_test_split(X,y, test_size =0.3)

from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score

model = LogisticRegression() 
model.fit(x_train, y_train)

# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1, penalty='l2',
#                    random_state=1, solver='liblinear', tol=0.0001,verbose=0, warm_start=False)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
## predict on validation set
pred_cv = model.predict(x_cv)
accuracy_score(y_cv,pred_cv)
# Out:
# 0.7783783783783784

# %% [markdown]
# validation score before feature engineering came out to be 77.8%

# %%
test['Credit_History'].fillna(test['Credit_History'].mode()[0], inplace=True)
test['LoanAmount'].fillna(test['LoanAmount'].median(), inplace=True)
test['LoanAmount_log'].fillna(test['LoanAmount_log'].median(), inplace=True)

# %% [markdown]
# Feauture Engineering

# %%
train['Total_Income']=train['ApplicantIncome']+train['CoapplicantIncome'] 
test['Total_Income']=test['ApplicantIncome']+test['CoapplicantIncome']
sns.distplot(train['Total_Income']);

# %%
# to remove skewness
train['Total_Income_log'] = np.log(train['Total_Income']) 
sns.distplot(train['Total_Income_log']); 
test['Total_Income_log'] = np.log(test['Total_Income'])

# %%
train['EMI']=train['LoanAmount']/train['Loan_Amount_Term'] 
test['EMI']=test['LoanAmount']/test['Loan_Amount_Term']
sns.distplot(train['EMI']);

# %%
train['Balance Income']=train['Total_Income']-(train['EMI']*1000) # Multiply with 1000 to make the units equal 
test['Balance Income']=test['Total_Income']-(test['EMI']*1000)
sns.distplot(train['Balance Income']);

# %%
# dropping independent variables used to create above features
train=train.drop(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term'], axis=1) 
test=test.drop(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term'], axis=1)

# %%
X = train.drop('Loan_Status',1) 
y = train.Loan_Status

# %%
#Logistic Regression
i=1 
kf = StratifiedKFold(n_splits=5,random_state=1,shuffle=True) 
for train_index,test_index in kf.split(X,y):     
    print('\n{} of kfold {}'.format(i,kf.n_splits))     
    xtr,xvl = X.loc[train_index],X.loc[test_index]     
    ytr,yvl = y[train_index],y[test_index]         

    model = LogisticRegression(random_state=1)     
    model.fit(xtr, ytr)     
    pred_test = model.predict(xvl)     
    score = accuracy_score(yvl,pred_test)     
    print('accuracy_score',score)     
    i+=1
# Out:
# 1 of kfold 5
# accuracy_score 0.7983870967741935
#
# 2 of kfold 5
# accuracy_score 0.8225806451612904
#
# 3 of kfold 5
# accuracy_score 0.7786885245901639
#
# 4 of kfold 5
# accuracy_score 0.7868852459016393
#
# 5 of kfold 5
# accuracy_score 0.8278688524590164

# %%
The validation accuracy after feature engineering came to be around 80%

# %%
# decision tree
from sklearn import tree
from sklearn.model_selection import StratifiedKFold
#Let’s fit the decision tree model with 5 folds of cross validation.

i=1 
kf = StratifiedKFold(n_splits=5,random_state=1,shuffle=True) 
for train_index,test_index in kf.split(X,y):     
    print('\n{} of kfold {}'.format(i,kf.n_splits))  
    i+=1 
    xtr,xvl = X.loc[train_index],X.loc[test_index]     
    ytr,yvl = y[train_index],y[test_index]         
    model = tree.DecisionTreeClassifier(random_state=1)     
    model.fit(xtr, ytr)     
    pred_test = model.predict(xvl)     
    score = accuracy_score(yvl,pred_test)     
    print('accuracy_score',score)
# Out:
# 1 of kfold 5
# accuracy_score 0.7258064516129032
#
# 2 of kfold 5
# accuracy_score 0.7419354838709677
#
# 3 of kfold 5
# accuracy_score 0.7049180327868853
#
# 4 of kfold 5
# accuracy_score 0.680327868852459
#
# 5 of kfold 5
# accuracy_score 0.7049180327868853

# %%
We see through decision tree model the accuracy was way less

# %%
from sklearn.ensemble import RandomForestClassifier
i=1 
kf = StratifiedKFold(n_splits=5,random_state=1,shuffle=True) 
for train_index,test_index in kf.split(X,y):     
    print('\n{} of kfold {}'.format(i,kf.n_splits)) 
    xtr,xvl = X.loc[train_index],X.loc[test_index]     
    ytr,yvl = y[train_index],y[test_index]         
    model = RandomForestClassifier(random_state=1, max_depth=10)     
    model.fit(xtr, ytr)     
    pred_test = model.predict(xvl)     
    score = accuracy_score(yvl,pred_test)     
    print('accuracy_score',score)     
    i+=1
# Out:
# 1 of kfold 5
# accuracy_score 0.8225806451612904
#
# 2 of kfold 5
# accuracy_score 0.8145161290322581
#
# 3 of kfold 5
# accuracy_score 0.7377049180327869
#
# 4 of kfold 5
# accuracy_score 0.7295081967213115
#
# 5 of kfold 5
# accuracy_score 0.8114754098360656

# %%
#random forest model gives accuracy of 78%
